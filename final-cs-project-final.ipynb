# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load
import seaborn as sns
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
#for dirname, _, filenames in os.walk('/kaggle/input'):
 #   for filename in filenames:
  #      print(os.path.join(dirname, filename))


df = pd.read_csv('/kaggle/input/ethereum-effect-pc-parts/FACT_GPU_PRICE.csv')
df1 = pd.read_csv('/kaggle/input/ethereum-effect-pc-parts/DIM_GPU_PROD.csv')
df2 = pd.read_csv('/kaggle/input/ethereum-effect-pc-parts/DIM_REGION.csv')
df3 = pd.read_csv('/kaggle/input/ethereum-effect-pc-parts/DIM_MERCHANT.csv')
df4 = pd.read_csv('/kaggle/input/ethereum-effect-pc-parts/FACT_CPU_PRICE.csv')
df5 = pd.read_csv('/kaggle/input/ethereum-effect-pc-parts/DIM_CPU_PROD.csv')
df6= pd.read_csv('/kaggle/input/ram-prod/DIM_RAM_PROD.csv')
df7 = pd.read_csv('/kaggle/input/ethereum-effect-pc-parts/FACT_RAM_PRICE.csv')










######################################### MERGING ##############################################################################################

# unqiue gpus for graphing purpouses only

#Gets the avarage prices for each unique prod by ProdID and finds the mean corresoponding to the product
average_prices = df.groupby('ProdId')['Price_USD'].mean().reset_index()
#merges the df with the avarage prodid in both df and adds clarrification to price columns
result_df = pd.merge(df, average_prices, on='ProdId', suffixes=('', '_average'))
#drops other duuplicate prod id since we only want 1 unqiue products
result_df = result_df.drop_duplicates(subset='ProdId')
#further clarifies the price
result_df = result_df.drop('Price_USD', axis=1).rename(columns={'price_average': 'Price_USD'})
#the following merges the product info with the region and mechant ( Merchant is reduntant since its unqiue GPU We ignore this column)
mdf = pd.merge(df1, result_df, left_on='Id', right_on='ProdId', how='inner')
ndf = pd.merge(mdf, df2, left_on = 'RegionId', right_on = 'Id', how = 'inner')
ldf = pd.merge(ndf, df3, left_on = 'MerchantId', right_on = 'Id', how = 'inner')
#Drop useless colums for our purposes
ldf = ldf.drop(columns=['Id_x','TimeId','Id_y'])
ldf = ldf[['Processor_Manufacturer','Processor','Memory_Capacity', 'ProdId', 'Price_USD_average' , 'Memory_Type']]
#This is for individual products stats not each production
#displays highest unqique priced GPUS for amd and nvidia
test1 = ldf[(ldf['Processor_Manufacturer'] == 'NVidia') & (ldf['Price_USD_average'] == ldf[ldf['Processor_Manufacturer'] == 'NVidia']['Price_USD_average'].max())]
display(test1)
test2 = ldf[(ldf['Processor_Manufacturer'] == 'AMD') & (ldf['Price_USD_average'] == ldf[ldf['Processor_Manufacturer'] == 'AMD']['Price_USD_average'].max())]
#Calcuulates avarage price per ram groupby for graphs
avg_price_per_memory = ldf.groupby('Processor_Manufacturer')['Price_USD_average'].sum() / ldf.groupby('Processor_Manufacturer')['Memory_Capacity'].sum()
avg_price_per_memory = avg_price_per_memory.reset_index(name='Price_USD_average')



# new dataset of all  individual GPU

#Just makes merging more easier we just found it more informitive and stuck to this format with later dataframes
df3 = df3.rename(columns={'Id': 'MerchantId'})
df2 = df2.rename(columns={'Id': 'RegionId'})
#after merging with region and merchant drop ids
gpu_price_df = pd.merge(df,df2,on="RegionId")
gpu_price_df = gpu_price_df.drop(columns=['RegionId'])
gpu_price_df = pd.merge(gpu_price_df,df3,on="MerchantId")
gpu_price_df = gpu_price_df.drop(columns=['MerchantId'])
#merges the info into the sets
merged_gpu = pd.merge(df1,gpu_price_df,left_on="Id",right_on="ProdId")
merged_gpu = merged_gpu.drop(columns=['ProdId','TimeId','Price_Original'])
display(merged_gpu)
mgp = merged_gpu.rename(columns={'Price_USD_y': 'Price_USD'})



# new dataset of all  individual CPU

#Merges to the Region and merchant df while dropping id that are no longer needed
cpu_price_df = pd.merge(df4,df2,on="RegionId")
cpu_price_df = cpu_price_df.drop(columns=['RegionId'])
cpu_price_df = pd.merge(cpu_price_df,df3,on="MerchantId")
cpu_price_df = cpu_price_df.drop(columns=['MerchantId'])
merged_cpu = pd.merge(df5,cpu_price_df,left_on="Id",right_on="ProdId")
merged_cpu = merged_cpu.drop(columns=['ProdId','TimeId','Price_Original'])
#sets index to manufacturer
merged_cpu = merged_cpu.set_index(['Manufacturer','Id'])
merged_cpu = merged_cpu.drop_duplicates()
merged_cpu = merged_cpu.sort_index()




#new dataset for individual ram

#merges the region and merchant on id and drops them
ram_price_df = pd.merge(df7,df2,on="RegionId")
ram_price_df = ram_price_df.drop(columns=['RegionId'])
ram_price_df = pd.merge(ram_price_df,df3,on="MerchantId")
ram_price_df = ram_price_df.drop(columns=['MerchantId'])
merged_ram = pd.merge(df6,ram_price_df,left_on="Id",right_on="ProdId")
# drop some other ids since they are not relevant to future data manipulation
merged_ram = merged_ram.drop(columns=['ProdId','TimeId'])
merged_ram = merged_ram.set_index(['Manufacturer','Id'])
merged_ram = merged_ram.drop_duplicates()
merged_ram = merged_ram.sort_index()
merged_ram

######################################################## Plotting ###################################################################################################


# Plot a bar chart
plt.figure(figsize=(10, 6))
#This  bar chart compares the companys by the avarage price per memory column that wes newly created 
plt.bar(avg_price_per_memory['Processor_Manufacturer'], avg_price_per_memory['Price_USD_average'], color='skyblue')
plt.xlabel('GPU Manufacturer')
plt.ylabel('Average Price per Memory Capacity')
plt.title('Average Price per Memory Capacity for Each Processor manufactor for GPU Model')
plt.show()

#box plot
ldf.boxplot(by ='Processor_Manufacturer', column =['Price_USD_average'], grid = False)
# This boxplot shows the ranges of the prices for the manufactures and has the outliers true by default
plt.title('Boxplot of Average Price by Processor Manufacturer for each type of GPU model')
plt.xlabel('Processor Manufacturer')
plt.ylabel('Average Price (USD)')
#sets figure size for visibility
plt.figure(figsize=(12, 8))


#Histogram

#gets all the unique meory types
memory_types = ldf['Memory_Type'].unique()
for memory_type in memory_types:
    #plots each unqiue mermory type frequency on the hisogram
    subset = ldf[ldf['Memory_Type'] == memory_type]
    plt.hist(subset['Price_USD_average'], bins=20, alpha=0.3, label=memory_type)


plt.title('Histogram of Average Price per Memory Capacity for All Processor Manufacturers (by Memory Type)')
plt.xlabel('Average Price (USD)')
plt.ylabel('Frequency')
plt.legend()
plt.grid(axis='y', alpha=0.3)
#makes the frequencies in terms of log to make data more visible
plt.yscale('log')
plt.show()



# make a pie chart of company sales percentage in US

#makes the total gpu unit data only GPU sold in US
USFILT = mgp[mgp['Code'] == 'us']
#combines both Newegg marketplace and Newegg into a singular Newegg
USFILT.loc[USFILT['Merchant'] == 'Newegg Marketplace', 'Merchant'] = 'Newegg'
#groupbys merchant 
merGB = USFILT.groupby('Merchant')
merGB = USFILT.groupby('Merchant').size().reset_index(name='Count')
display(MerRe)
plt.figure(figsize=(8, 8))
plt.pie(MerRe['Count'], labels=MerRe['Merchant'], autopct='%1.1f%%', startangle=140)
plt.title('Merchant Distribution In the US')
plt.show()

# Filters only for canada
nde = mgp[mgp['Code'] == 'ca']
#only keeps nessecary columns for group by
nde = nde[['Merchant', 'Price_USD', 'Memory_Capacity']]
#combines both Newegg marketplace and Newegg into a singular Newegg
nde['Merchant'] = nde['Merchant'].replace({'Newegg Canada Marketplace': 'Newegg Canada'})
newlt = nde.groupby('Merchant')
disy = newlt.mean()
plt.figure(figsize=(8, 6))
#uses seaborn to grap vram by price for each seller as a scatter plot
sns.scatterplot(x='Memory_Capacity', y='Price_USD', hue='Merchant', data=disy, palette='viridis', s=100)
plt.title('Mean Price USD by Mean VRAM and Merchant per individual gpu in canada')
plt.xlabel('Memory Capacity')
plt.ylabel('Price USD')
plt.legend(title='Merchant')
plt.show()


########################################### Filtering/ Cleaning/ Pivoting ##############################################################


### Ram cleaning/Filtering
merged_ram = merged_ram.reset_index()
for x in range(100):
    if x % 2 == 1 or x % 5 == 0:
        merged_ram.loc[x, 'Price_USD'] = np.NaN
    if x % 2 == 0 and x % 3 == 0:
        merged_ram.loc[x, 'Speed'] = np.NaN

# shortens dataframe to make it manageable
merged_ram = merged_ram.head(100)

# interpolate the data
merged_ram = merged_ram.interpolate()

# interpolating doesn't remove the first NaN values, so we use bfill to get rid of those
merged_ram = merged_ram.bfill()

# now we filter by pricing
merged_ram = merged_ram[merged_ram['Price_USD'] < 13]
merged_ram = merged_ram.reset_index()

# an index column is added from when we reset the index, so we drop this column
merged_ram = merged_ram.drop('index', axis=1)


# more random ways of inserting NA values
for x in range(len(merged_ram)):
    if x % 2 == 1:
        merged_ram.loc[x, 'Speed'] = np.NaN
    if x % 3 == 0:
        merged_ram.loc[x, 'Price_Original'] = np.NaN

merged_ram = merged_ram.fillna(0)
merged_ram = merged_ram.sort_values(by='Price_Original')

# now we have an extremely small dataframe with a particular set of gpus (only 12 left)
# take out the rows that were filled with 0s using filtering
merged_ram = merged_ram[(merged_ram['Price_Original'] != 0) & (merged_ram['Speed'] != 0)]

# 4 GPUS priced less than 13 USD whos original index was not used to insert NA values
display(merged_ram)
### Pivoting
ram_product_df = df6.reset_index()
ram_product_df = ram_product_df.set_index('Id').sort_index().drop('RAM_Name', axis=1).drop_duplicates(subset=['Manufacturer', 'Memory_Type']) 
ram_pivot_df = ram_product_df.pivot(index=['Manufacturer'], columns=['Memory_Type'], values=['Speed']) 
display(ram_pivot_df)




# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
#     Processor_Manufacturer     Processor  Memory_Capacity  ProdId  \
# 349                 NVidia  Quadro GP100             16.0    2002
#
#      Price_USD_average Memory_Type
# 349        8899.593236        HBM2
#           Id Processor_Manufacturer    Processor GPU_Manufacturer  \
# 0          1                    AMD         C420           Matrox
# 1          1                    AMD         C420           Matrox
# 2          1                    AMD         C420           Matrox
# 3          1                    AMD         C420           Matrox
# 4          1                    AMD         C420           Matrox
# ...      ...                    ...          ...              ...
# 997151  2054                 NVidia  Quadro P620              PNY
# 997152  2054                 NVidia  Quadro P620              PNY
# 997153  2054                 NVidia  Quadro P620              PNY
# 997154  2054                 NVidia  Quadro P620              PNY
# 997155  2054                 NVidia  Quadro P620              PNY
#
#         Memory_Capacity Memory_Type   Price_USD Code Currency  \
# 0                   2.0       GDDR5  601.738413   de      EUR
# 1                   2.0       GDDR5  551.885276   de      EUR
# 2                   2.0       GDDR5  548.098896   de      EUR
# 3                   2.0       GDDR5  545.093860   de      EUR
# 4                   2.0       GDDR5  544.674245   de      EUR
# ...                 ...         ...         ...  ...      ...
# 997151              2.0       GDDR5  261.254103   de      EUR
# 997152              2.0       GDDR5  263.058996   de      EUR
# 997153              2.0       GDDR5  261.517908   de      EUR
# 997154              2.0       GDDR5  260.038547   de      EUR
# 997155              2.0       GDDR5  259.480216   de      EUR
#
#                 Merchant
# 0       geizhals_unknown
# 1       geizhals_unknown
# 2       geizhals_unknown
# 3       geizhals_unknown
# 4       geizhals_unknown
# ...                  ...
# 997151  geizhals_unknown
# 997152  geizhals_unknown
# 997153  geizhals_unknown
# 997154  geizhals_unknown
# 997155  geizhals_unknown
#
# [997156 rows x 10 columns]
#      Merchant  Count
# 8      Newegg    765
# 13  SuperBiiz    326
# 1         B H    258
# 11   OutletPC    212
# 12        PCM    141
# 0       other    431
#    Manufacturer  Id RAM_Name Memory_Type  Speed  Capacity  Price_USD  \
# 2         ADATA   1    Adata         DDR  400.0       0.5  12.947509
# 4         ADATA   1    Adata         DDR  400.0       0.5  12.853993
# 8         ADATA   1    Adata         DDR  400.0       0.5  12.868519
# 10        ADATA   1    Adata         DDR  400.0       0.5  12.851848
# 14        ADATA   1    Adata         DDR  400.0       0.5  12.858866
# 16        ADATA   1    Adata         DDR  400.0       0.5  12.775268
#
#     Price_Original Code Currency          Merchant
# 2            9.790   de      EUR  geizhals_unknown
# 4            9.795   de      EUR  geizhals_unknown
# 8            9.870   de      EUR  geizhals_unknown
# 10           9.885   de      EUR  geizhals_unknown
# 14           9.955   de      EUR  geizhals_unknown
# 16           9.955   de      EUR  geizhals_unknown
#               Speed
# Memory_Type     DDR    DDR2    DDR3   DDR3L   DDR3U    DDR4    SDR
# Manufacturer
# ADATA         400.0   667.0  1066.0  1600.0     NaN  2400.0    NaN
# AENEON          NaN   667.0     NaN     NaN     NaN     NaN    NaN
# AFOX            NaN     NaN     NaN     NaN     NaN  2400.0    NaN
# AMD             NaN     NaN  1600.0     NaN     NaN  2133.0    NaN
# APACER        400.0   533.0  1066.0  1066.0     NaN  2133.0    NaN
# APOTOP          NaN     NaN  1333.0     NaN     NaN     NaN    NaN
# AVEXIR          NaN     NaN  1333.0     NaN     NaN  2133.0    NaN
# BUFFALO         NaN     NaN  1333.0     NaN     NaN     NaN    NaN
# COMPUSTOCX      NaN   533.0  1066.0     NaN     NaN     NaN    NaN
# CORSAIR       266.0   533.0  1333.0  1600.0     NaN  2133.0    NaN
# CRUCIAL       333.0   667.0  1066.0  1333.0     NaN  2400.0    NaN
# DANE-ELEC       NaN   667.0     NaN     NaN     NaN     NaN    NaN
# DELL            NaN     NaN  1600.0     NaN     NaN     NaN    NaN
# EDGE            NaN     NaN     NaN     NaN     NaN  2666.0    NaN
# ELIXIR        400.0   800.0  1333.0  1333.0     NaN     NaN    NaN
# EVGA            NaN     NaN  1600.0     NaN     NaN  2666.0    NaN
# EXTREMEMORY   333.0  1066.0     NaN     NaN     NaN     NaN  133.0
# G.SKILL       400.0   533.0  1066.0  1333.0  1600.0  3200.0    NaN
# GALAX           NaN     NaN     NaN     NaN     NaN  3200.0    NaN
# GALAX/KFA2      NaN     NaN     NaN     NaN     NaN  3200.0    NaN
# GEIL            NaN   533.0  1333.0  1333.0     NaN  2133.0    NaN
# GLOWAY          NaN     NaN     NaN     NaN     NaN  2400.0    NaN
# GOODRAM         NaN   667.0  1333.0  1600.0     NaN  2133.0    NaN
# HP              NaN   800.0  1333.0  1866.0     NaN     NaN    NaN
# HYNIX           NaN   533.0   667.0     NaN     NaN  2400.0    NaN
# IBM             NaN     NaN  1600.0     NaN     NaN     NaN    NaN
# INTEGRAL        NaN   800.0  1066.0     NaN     NaN     NaN    NaN
# INTENSO         NaN     NaN  1600.0     NaN     NaN  2133.0    NaN
# KINGMAX       400.0   800.0  1333.0     NaN     NaN     NaN    NaN
# KINGSTON      400.0   533.0  1066.0  1866.0     NaN  2133.0  100.0
# KLEVV           NaN     NaN  1600.0     NaN     NaN  2133.0    NaN
# LEXAR           NaN     NaN  1600.0     NaN     NaN     NaN    NaN
# MDT           400.0     NaN     NaN     NaN     NaN     NaN    NaN
# MICRON          NaN   400.0  1066.0  1866.0     NaN  2133.0    NaN
# MUSHKIN       333.0   533.0  1066.0  1600.0     NaN  2666.0  133.0
# MUSTANG       400.0   667.0  1600.0     NaN     NaN     NaN    NaN
# NILOX           NaN   667.0  1333.0     NaN     NaN  2133.0    NaN
# OCZ             NaN   667.0  1600.0     NaN     NaN     NaN    NaN
# PANRAM          NaN     NaN  1333.0     NaN     NaN  2400.0    NaN
# PAREEMA         NaN     NaN  1333.0     NaN     NaN     NaN    NaN
# PATRIOT         NaN   800.0  1333.0     NaN     NaN  2133.0    NaN
# PNY             NaN   800.0  1333.0     NaN     NaN  2133.0    NaN
# SAMSUNG         NaN   667.0  1066.0  1600.0     NaN  2133.0    NaN
# SILICON         NaN     NaN  1333.0     NaN     NaN  2133.0    NaN
# SK              NaN     NaN  1066.0  1600.0     NaN  2133.0    NaN
# SUPER           NaN     NaN  1333.0     NaN     NaN     NaN    NaN
# TEAM GROUP      NaN   800.0  1600.0  1866.0     NaN  2133.0    NaN
# TOSHIBA         NaN     NaN  1600.0     NaN     NaN     NaN    NaN
# TRANSCEND       NaN   533.0  1066.0     NaN     NaN  2133.0    NaN
# V7              NaN     NaN  1333.0     NaN     NaN  2400.0    NaN
# VISIONTEK       NaN   800.0  1333.0     NaN     NaN     NaN    NaN
# WINTEC          NaN   667.0  1333.0     NaN     NaN  2133.0    NaN
# XPG             NaN     NaN     NaN     NaN     NaN  2400.0    NaN
